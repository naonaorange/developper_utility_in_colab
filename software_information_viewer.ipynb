# %% [markdown]
# # Python version

# %%
# !python -V
# Out:
# Python 3.7.10

# %% [markdown]
# # Library software version

# %%
import tensorflow as tf
print('Tensorflow library version : ' + str(tf.__version__))

import numpy
print('numpy library version : ' + str(numpy.__version__))

import scipy
print('scipy library version : ' + str(scipy.__version__))

import sklearn
print('sklearn library version : ' + str(sklearn.__version__))
# Out:
# Tensorflow library version : 2.4.1
# numpy library version : 1.19.5
# scipy library version : 1.4.1
# sklearn library version : 0.22.2.post1
